# %%
# !git clone https://github.com/PhonePe/pulse
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 14076, done.
# remote: Counting objects: 100% (4500/4500), done.
# remote: Compressing objects: 100% (2703/2703), done.
# remote: Total 14076 (delta 1819), reused 4274 (delta 1604), pack-reused 9576
# Receiving objects: 100% (14076/14076), 20.38 MiB | 3.63 MiB/s, done.
# Resolving deltas: 100% (6038/6038), done.

# %%
import pandas as pd
import json
import os

# %%
path = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/transaction/country/india/state/'
aggregated_state_list=os.listdir(path)

# %%
aggregated_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'tamil-nadu',
#  '.DS_Store',
#  'lakshadweep',
#  'telangana',
#  'manipur',
#  'haryana',
#  'gujarat',
#  'sikkim',
#  'delhi',
#  'west-bengal',
#  'uttar-pradesh',
#  'goa',
#  'punjab',
#  'arunachal-pradesh',
#  'karnataka',
#  'jammu-&-kashmir',
#  'maharashtra',
#  'odisha',
#  'madhya-pradesh',
#  'rajasthan',
#  'andhra-pradesh',
#  'chandigarh',
#  'kerala',
#  'chhattisgarh',
#  'tripura',
#  'mizoram',
#  'himachal-pradesh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'ladakh',
#  'assam',
#  'meghalaya',
#  'uttarakhand',
#  'puducherry',
#  'bihar',
#  'jharkhand',
#  'nagaland']

# %%
#dataframe fo aggregated transaction

# %%
import os
import json
import pandas as pd

# Define the path to the transaction data
path = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/transaction/country/india/state'
aggregated_state_list = [state for state in os.listdir(path) if os.path.isdir(os.path.join(path, state))]

# Initialize dictionary to store data for DataFrame creation
column = {
    'Transaction_type': [],
    'Transaction_count': [],
    'Transaction_amount': [],
    'State': [],
    'Year': [],
    'Quarter': []
}

# Check if the given path exists
if not os.path.exists(path):
    raise FileNotFoundError(f"The specified path does not exist: {path}")

# Iterate through state directories
for state in aggregated_state_list:
    state_path = os.path.join(path, state)
    year_list = [year for year in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, year))]

    for year in year_list:
        year_path = os.path.join(state_path, year)
        files = os.listdir(year_path)

        for file in files:
            file_path = os.path.join(year_path, file)

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    file_content = json.load(f)

                # Extract transaction data
                transaction_data = file_content.get("data", {}).get("transactionData", [])

                for transaction in transaction_data:
                    type_of_payment = transaction.get("name", "Unknown")
                    count = transaction.get("paymentInstruments", [])[0].get("count", 0)
                    amount = transaction.get("paymentInstruments", [])[0].get("amount", 0)

                    # Add data to the dictionary
                    column['Transaction_type'].append(type_of_payment)
                    column['Transaction_count'].append(count)
                    column['Transaction_amount'].append(amount)
                    column['State'].append(state)
                    column['Year'].append(year)
                    column['Quarter'].append(int(file.strip('.json')))

            except FileNotFoundError:
                print(f"File not found: {file_path}")
            except json.JSONDecodeError:
                print(f"Error decoding JSON in {file_path}")
            except Exception as e:
                print(f"An unexpected error occurred: {e}")

# Create DataFrame from the dictionary
df_aggregated_trans = pd.DataFrame(column)

df_aggregated_trans
# Out:
#               Transaction_type  Transaction_count  Transaction_amount  \
# 0        Peer-to-peer payments             342649        1.682329e+09
# 1            Merchant payments             284298        3.700916e+08
# 2     Recharge & bill payments             163401        7.130013e+07
# 3           Financial Services               1757        2.869682e+06
# 4                       Others               2643        2.440322e+06
# ...                        ...                ...                 ...
# 4309  Recharge & bill payments              72881        1.661551e+07
# 4310     Peer-to-peer payments              53723        3.589263e+08
# 4311         Merchant payments              10350        1.050063e+07
# 4312        Financial Services                587        2.161274e+05
# 4313                    Others               1792        1.754940e+06
#
#                           State  Year  Quarter
# 0     andaman-&-nicobar-islands  2022        1
# ...

# %%
#dataframe fo aggregated user

# %%
import os
import json
import pandas as pd

# Define the path to the user data
path_user = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/user/country/india/state/'


# Initialize a dictionary to store data for DataFrame creation
data_dict = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Brand': [],
    'Count': [],
    'Percentage': []
}

# Get the list of state directories
states = [state for state in os.listdir(path_user) if os.path.isdir(os.path.join(path_user, state))]

for state in states:
    state_path = os.path.join(path_user, state)
    years = [year for year in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, year))]

    for year in years:
        year_path = os.path.join(state_path, year)
        files = os.listdir(year_path)

        for file in files:
            file_path = os.path.join(year_path, file)

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    file_content = json.load(f)

                # Extract usersByDevice data
                users_by_device = file_content.get("data", {}).get("usersByDevice", [])

                if not users_by_device:
                    print(f"No 'usersByDevice' found in {file_path}")
                    continue

                # Append data to the dictionary
                quarter = int(file.strip('.json'))

                for device in users_by_device:
                    brand = device.get("brand", "Unknown")
                    count = device.get("count", 0)
                    percentage = device.get("percentage", 0)

                    data_dict['Brand'].append(brand)
                    data_dict['Count'].append(count)
                    data_dict['Percentage'].append(percentage)
                    data_dict['State'].append(state)
                    data_dict['Year'].append(year)
                    data_dict['Quarter'].append(quarter)

            except FileNotFoundError:
                print(f"File not found: {file_path}")
            except json.JSONDecodeError:
                print(f"Error decoding JSON in {file_path}")
            except Exception as e:
                print(f"An unexpected error occurred: {e}")

# Create a DataFrame from the data dictionary
df_aggregated_user = pd.DataFrame(data_dict)
# Out:
# No 'usersByDevice' found in /Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/user/country/india/state/andaman-&-nicobar-islands/2022/2.json
# No 'usersByDevice' found in /Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/user/country/india/state/andaman-&-nicobar-islands/2022/3.json
# No 'usersByDevice' found in /Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/user/country/india/state/andaman-&-nicobar-islands/2022/4.json
# No 'usersByDevice' found in /Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/user/country/india/state/andaman-&-nicobar-islands/2023/1.json
# No 'usersByDevice' found in /Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/user/country/india/state/andaman-&-nicobar-islands/2023/2.json
# ...

# %%
df_aggregated_user
# Out:
#                           State  Year  Quarter    Brand  Count  Percentage
# 0     andaman-&-nicobar-islands  2022        1     Vivo  18688    0.244966
# 1     andaman-&-nicobar-islands  2022        1   Xiaomi  17957    0.235384
# 2     andaman-&-nicobar-islands  2022        1  Samsung  12955    0.169817
# 3     andaman-&-nicobar-islands  2022        1   Realme   6769    0.088730
# 4     andaman-&-nicobar-islands  2022        1     Oppo   6461    0.084692
# ...                         ...   ...      ...      ...    ...         ...
# 6727                   nagaland  2018        4    Apple   1148    0.026700
# 6728                   nagaland  2018        4   Lenovo   1024    0.023816
# 6729                   nagaland  2018        4   Huawei    849    0.019746
# 6730                   nagaland  2018        4     Asus    840    0.019536
# 6731                   nagaland  2018        4   Others   6249    0.145336
#
# [6732 rows x 6 columns]

# %%
# map_trans

# %%
# Define the path to the map transaction data
path_map_trans = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/map/transaction/hover/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_map_trans) if os.path.isdir(os.path.join(path_map_trans, item))]

# Initialize dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'District': [],
    'Count': [],
    'Amount': [],
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_map_trans, state)

    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]
    
    # Iterate through each year directory within the state
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = os.listdir(cur_year)

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            # Extract hoverDataList and required metrics
            hover_data_list = file_content.get("data", {}).get("hoverDataList", [])

            for item in hover_data_list:
                district = item["name"]
                metrics = item.get("metric", [])

                for metric in metrics:
                    if metric["type"] == "TOTAL":
                        count = metric["count"]
                        amount = metric["amount"]

                        # Append data to the dictionary
                        columns["District"].append(district)
                        columns["Count"].append(count)
                        columns["Amount"].append(amount)
                        columns["State"].append(state)
                        columns["Year"].append(year)
                        columns["Quarter"].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_map_trans = pd.DataFrame(columns)
df_map_trans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2022        1
# 1      andaman-&-nicobar-islands  2022        1
# 2      andaman-&-nicobar-islands  2022        1
# 3      andaman-&-nicobar-islands  2022        2
# 4      andaman-&-nicobar-islands  2022        2
# ...                          ...   ...      ...
# 17559                   nagaland  2018        4
# 17560                   nagaland  2018        4
# 17561                   nagaland  2018        4
# 17562                   nagaland  2018        4
# 17563                   nagaland  2018        4
#
#                                 District   Count        Amount
# 0      north and middle andaman district   60059  1.616249e+08
# 1                 south andaman district  705512  1.872991e+09
# 2                      nicobars district   29177  9.441413e+07
# 3      north and middle andaman district   72573  1.956932e+08
# 4                 south andaman district  954875  2.357327e+09
# ...

# %%
# map_user

# %%
import os
import json
import pandas as pd

# Define the path to the map user data
path_map_user = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/map/user/hover/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_map_user) if os.path.isdir(os.path.join(path_map_user, item))]

# Initialize a dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'District': [],
    'RegisteredUser': [],
    'AppOpens': [],
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_map_user, state)

    # Get list of year directories within the state
    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]

    # Iterate through each year directory
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = [file for file in os.listdir(cur_year) if file.endswith('.json')]

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            # Extract hoverData and required metrics
            hover_data = file_content.get("data", {}).get("hoverData", {})

            # Now `hover_data` is a dictionary, not a list
            for district_name, metrics in hover_data.items():
                registereduser = metrics.get("registeredUsers", 0)
                appopens = metrics.get("appOpens", 0)

                # Append data to the dictionary
                columns["District"].append(district_name)
                columns["RegisteredUser"].append(registereduser)
                columns["AppOpens"].append(appopens)
                columns["State"].append(state)
                columns["Year"].append(year)
                columns["Quarter"].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_map_user = pd.DataFrame(columns)

df_map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2022        1
# 1      andaman-&-nicobar-islands  2022        1
# 2      andaman-&-nicobar-islands  2022        1
# 3      andaman-&-nicobar-islands  2022        2
# 4      andaman-&-nicobar-islands  2022        2
# ...                          ...   ...      ...
# 17563                   nagaland  2018        4
# 17564                   nagaland  2018        4
# 17565                   nagaland  2018        4
# 17566                   nagaland  2018        4
# 17567                   nagaland  2018        4
#
#                                 District  RegisteredUser  AppOpens
# 0      north and middle andaman district           10720    904869
# 1                 south andaman district           63487   2368756
# 2                      nicobars district            2081    573782
# 3      north and middle andaman district           11379    963824
# ...

# %%
# top_Trans

# %%
# Define the path to the top transaction data
path_top_trans = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/top/transaction/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_top_trans) if os.path.isdir(os.path.join(path_top_trans, item))]

# Initialize dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Pincode': [],
    'Transaction_count': [],
    'Transaction_amount': [],
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_top_trans, state)

    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]
    
    # Iterate through each year directory within the state
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = os.listdir(cur_year)

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            # Extract hoverDataList and required metrics
            for i in file_content['data']['pincodes']:
                name = i['entityName']
                count = i['metric']['count']
                amount = i['metric']['amount']
                columns['Pincode'].append(name)
                columns['Transaction_count'].append(count)
                columns['Transaction_amount'].append(amount)
                columns['State'].append(state)
                columns['Year'].append(year)
                columns['Quarter'].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_top_trans = pd.DataFrame(columns)
df_top_trans
# Out:
#                           State  Year  Quarter Pincode  Transaction_count  \
# 0     andaman-&-nicobar-islands  2022        1  744101             209941
# 1     andaman-&-nicobar-islands  2022        1  744103             157230
# 2     andaman-&-nicobar-islands  2022        1  744105             122716
# 3     andaman-&-nicobar-islands  2022        1  744102              74883
# 4     andaman-&-nicobar-islands  2022        1  744104              32471
# ...                         ...   ...      ...     ...                ...
# 8562                   nagaland  2018        4  797113               5861
# 8563                   nagaland  2018        4  798601               5806
# 8564                   nagaland  2018        4  797117               4640
# 8565                   nagaland  2018        4  797118               4531
# 8566                   nagaland  2018        4  797116               4309
#
#       Transaction_amount
# 0           6.159781e+08
# 1           3.997160e+08
# ...

# %%
#top user

# %%
import os
import json
import pandas as pd

# Define the path to the map user data
path_top_user = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/top/user/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_top_user) if os.path.isdir(os.path.join(path_top_user, item))]

# Initialize a dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Pincode': [],
    'RegisteredUsers': []
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_top_user, state)

    # Get list of year directories within the state
    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]

    # Iterate through each year directory
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = [file for file in os.listdir(cur_year) if file.endswith('.json')]

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            for i in file_content['data']['pincodes']:
                name = i['name']
                registeredUsers = i['registeredUsers']
                columns['Pincode'].append(name)
                columns['RegisteredUsers'].append(registeredUsers)
                columns['State'].append(state)
                columns['Year'].append(year)
                columns['Quarter'].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_top_user = pd.DataFrame(columns)

df_top_user
# Out:
#                           State  Year  Quarter Pincode  RegisteredUsers
# 0     andaman-&-nicobar-islands  2022        1  744103            15011
# 1     andaman-&-nicobar-islands  2022        1  744105            13070
# 2     andaman-&-nicobar-islands  2022        1  744101            12300
# 3     andaman-&-nicobar-islands  2022        1  744102             8271
# 4     andaman-&-nicobar-islands  2022        1  744202             4107
# ...                         ...   ...      ...     ...              ...
# 8563                   nagaland  2018        4  797120             2071
# 8564                   nagaland  2018        4  798601             1972
# 8565                   nagaland  2018        4  797117             1752
# 8566                   nagaland  2018        4  797118             1604
# 8567                   nagaland  2018        4  797116             1410
#
# [8568 rows x 5 columns]

# %%
#Converting pandas Dataframe into CSV files
df_aggregated_trans.to_csv('agg_trans.csv',index=False)
df_aggregated_user.to_csv('agg_user.csv',index=False)
df_map_trans.to_csv('map_trans.csv',index=False)
df_map_user.to_csv('map_user.csv',index=False)
df_top_trans.to_csv('top_trans.csv',index=False)
df_top_user.to_csv('top_user.csv',index=False)
#Creating a Statenames CSV file 
df_aggregated_trans["State"].to_csv("Statenames.csv",index=False)

# %%
import pandas as pd
from sqlalchemy import create_engine, Table, Column, String, Integer, Float, MetaData, text

engine = create_engine("mysql+mysqlconnector://root:Blue9791@localhost/")

# Create a new database if it doesn't exist
with engine.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS phonepe_pulse"))

# Create SQLAlchemy engine and connect to MySQL
engine = create_engine("mysql+mysqlconnector://root:Blue9791@localhost/phonepe_pulse")

# MetaData is used to hold information about tables and database
metadata = MetaData()

# Define table structures
agg_trans = Table('agg_trans', metadata,
                  Column('State', String(100)),
                  Column('Year', Integer),
                  Column('Quarter', Integer),
                  Column('Transaction_type', String(100)),
                  Column('Transaction_count', Integer),
                  Column('Transaction_amount', Float))

agg_user = Table('agg_user', metadata,
                 Column('State', String(100)),
                 Column('Year', Integer),
                 Column('Quarter', Integer),
                 Column('Brand', String(100)),
                 Column('Count', Integer),
                 Column('Percentage', Float))

# Continue with other tables in a similar fashion
map_trans = Table('map_trans', metadata,
                  Column('State', String(100)),
                  Column('Year', Integer),
                  Column('Quarter', Integer),
                  Column('District', String(100)),
                  Column('Count', Integer),
                  Column('Amount', Float))

map_user = Table('map_user', metadata,
                 Column('State', String(100)),
                 Column('Year', Integer),
                 Column('Quarter', Integer),
                 Column('District', String(100)),
                 Column('RegisteredUser', Integer),
                 Column('AppOpens', Integer))

top_trans = Table('top_trans', metadata,
                  Column('State', String(100)),
                  Column('Year', Integer),
                  Column('Quarter', Integer),
                  Column('Pincode', Integer),
                  Column('Transaction_count', Integer),
                  Column('Transaction_amount', Float))

top_user = Table('top_user', metadata,
                 Column('State', String(100)),
                 Column('Year', Integer),
                 Column('Quarter', Integer),
                 Column('Pincode', Integer),
                 Column('RegisteredUsers', Integer))

# Create tables in the database
metadata.create_all(engine)

# Load CSV files into the SQLAlchemy tables
agg_trans_df = pd.read_csv("agg_trans.csv")
agg_user_df = pd.read_csv("agg_user.csv")
map_trans_df = pd.read_csv("map_trans.csv")
map_user_df = pd.read_csv("map_user.csv")
top_trans_df = pd.read_csv("top_trans.csv")
top_user_df = pd.read_csv("top_user.csv")

# Use pandas to_sql to insert data into SQLAlchemy tables
agg_trans_df.to_sql('agg_trans', engine, if_exists='append', index=False)
agg_user_df.to_sql('agg_user', engine, if_exists='append', index=False)
map_trans_df.to_sql('map_trans', engine, if_exists='append', index=False)
map_user_df.to_sql('map_user', engine, if_exists='append', index=False)
top_trans_df.to_sql('top_trans', engine, if_exists='append', index=False)
top_user_df.to_sql('top_user', engine, if_exists='append', index=False)
# Out:
# 8568

# %%
from sqlalchemy import inspect

# Inspect the existing table schema to verify its columns
inspector = inspect(engine)
columns = [col['name'] for col in inspector.get_columns('agg_user')]
print(columns)
# Out:
# ['State', 'Year', 'Quarter', 'Brands', 'Count', 'Percentage']

# %%
# Create an inspector to inspect the database
inspector = inspect(engine)

# Get the list of all tables in the current database/schema
tables = inspector.get_table_names()

# Print each table name
for table in tables:
    print(table)
# Out:
# agg_trans
# agg_user
# map_trans
# map_user
# top_trans
# top_user

# %%
import pandas as pd
import json
import os
path = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/transaction/country/india/state/'
aggregated_state_list=os.listdir(path)
import os
import json
import pandas as pd

# Define the path to the transaction data
path = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/transaction/country/india/state'
aggregated_state_list = [state for state in os.listdir(path) if os.path.isdir(os.path.join(path, state))]

# Initialize dictionary to store data for DataFrame creation
column = {
    'Transaction_type': [],
    'Transaction_count': [],
    'Transaction_amount': [],
    'State': [],
    'Year': [],
    'Quarter': []
}

# Check if the given path exists
if not os.path.exists(path):
    raise FileNotFoundError(f"The specified path does not exist: {path}")

# Iterate through state directories
for state in aggregated_state_list:
    state_path = os.path.join(path, state)
    year_list = [year for year in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, year))]

    for year in year_list:
        year_path = os.path.join(state_path, year)
        files = os.listdir(year_path)

        for file in files:
            file_path = os.path.join(year_path, file)

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    file_content = json.load(f)

                # Extract transaction data
                transaction_data = file_content.get("data", {}).get("transactionData", [])

                for transaction in transaction_data:
                    type_of_payment = transaction.get("name", "Unknown")
                    count = transaction.get("paymentInstruments", [])[0].get("count", 0)
                    amount = transaction.get("paymentInstruments", [])[0].get("amount", 0)

                    # Add data to the dictionary
                    column['Transaction_type'].append(type_of_payment)
                    column['Transaction_count'].append(count)
                    column['Transaction_amount'].append(amount)
                    column['State'].append(state)
                    column['Year'].append(year)
                    column['Quarter'].append(int(file.strip('.json')))

            except FileNotFoundError:
                print(f"File not found: {file_path}")
            except json.JSONDecodeError:
                print(f"Error decoding JSON in {file_path}")
            except Exception as e:
                print(f"An unexpected error occurred: {e}")

# Create DataFrame from the dictionary
df_aggregated_trans = pd.DataFrame(column)

df_aggregated_trans
import os
import json
import pandas as pd

# Define the path to the user data
path_user = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/aggregated/user/country/india/state/'


# Initialize a dictionary to store data for DataFrame creation
data_dict = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Brand': [],
    'Count': [],
    'Percentage': []
}

# Get the list of state directories
states = [state for state in os.listdir(path_user) if os.path.isdir(os.path.join(path_user, state))]

for state in states:
    state_path = os.path.join(path_user, state)
    years = [year for year in os.listdir(state_path) if os.path.isdir(os.path.join(state_path, year))]

    for year in years:
        year_path = os.path.join(state_path, year)
        files = os.listdir(year_path)

        for file in files:
            file_path = os.path.join(year_path, file)

            try:
                with open(file_path, 'r', encoding='utf-8') as f:
                    file_content = json.load(f)

                # Extract usersByDevice data
                users_by_device = file_content.get("data", {}).get("usersByDevice", [])

                if not users_by_device:
                    print(f"No 'usersByDevice' found in {file_path}")
                    continue

                # Append data to the dictionary
                quarter = int(file.strip('.json'))

                for device in users_by_device:
                    brand = device.get("brand", "Unknown")
                    count = device.get("count", 0)
                    percentage = device.get("percentage", 0)

                    data_dict['Brand'].append(brand)
                    data_dict['Count'].append(count)
                    data_dict['Percentage'].append(percentage)
                    data_dict['State'].append(state)
                    data_dict['Year'].append(year)
                    data_dict['Quarter'].append(quarter)

            except FileNotFoundError:
                print(f"File not found: {file_path}")
            except json.JSONDecodeError:
                print(f"Error decoding JSON in {file_path}")
            except Exception as e:
                print(f"An unexpected error occurred: {e}")

# Create a DataFrame from the data dictionary
df_aggregated_user = pd.DataFrame(data_dict)


# Define the path to the map transaction data
path_map_trans = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/map/transaction/hover/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_map_trans) if os.path.isdir(os.path.join(path_map_trans, item))]

# Initialize dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'District': [],
    'Count': [],
    'Amount': [],
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_map_trans, state)

    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]
    
    # Iterate through each year directory within the state
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = os.listdir(cur_year)

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            # Extract hoverDataList and required metrics
            hover_data_list = file_content.get("data", {}).get("hoverDataList", [])

            for item in hover_data_list:
                district = item["name"]
                metrics = item.get("metric", [])

                for metric in metrics:
                    if metric["type"] == "TOTAL":
                        count = metric["count"]
                        amount = metric["amount"]

                        # Append data to the dictionary
                        columns["District"].append(district)
                        columns["Count"].append(count)
                        columns["Amount"].append(amount)
                        columns["State"].append(state)
                        columns["Year"].append(year)
                        columns["Quarter"].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_map_trans = pd.DataFrame(columns)
df_map_trans

import os
import json
import pandas as pd

# Define the path to the map user data
path_map_user = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/map/user/hover/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_map_user) if os.path.isdir(os.path.join(path_map_user, item))]

# Initialize a dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'District': [],
    'RegisteredUser': [],
    'AppOpens': [],
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_map_user, state)

    # Get list of year directories within the state
    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]

    # Iterate through each year directory
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = [file for file in os.listdir(cur_year) if file.endswith('.json')]

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            # Extract hoverData and required metrics
            hover_data = file_content.get("data", {}).get("hoverData", {})

            # Now `hover_data` is a dictionary, not a list
            for district_name, metrics in hover_data.items():
                registereduser = metrics.get("registeredUsers", 0)
                appopens = metrics.get("appOpens", 0)

                # Append data to the dictionary
                columns["District"].append(district_name)
                columns["RegisteredUser"].append(registereduser)
                columns["AppOpens"].append(appopens)
                columns["State"].append(state)
                columns["Year"].append(year)
                columns["Quarter"].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_map_user = pd.DataFrame(columns)

df_map_user


# Define the path to the top transaction data
path_top_trans = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/top/transaction/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_top_trans) if os.path.isdir(os.path.join(path_top_trans, item))]

# Initialize dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Pincode': [],
    'Transaction_count': [],
    'Transaction_amount': [],
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_top_trans, state)

    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]
    
    # Iterate through each year directory within the state
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = os.listdir(cur_year)

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            # Extract hoverDataList and required metrics
            for i in file_content['data']['pincodes']:
                name = i['entityName']
                count = i['metric']['count']
                amount = i['metric']['amount']
                columns['Pincode'].append(name)
                columns['Transaction_count'].append(count)
                columns['Transaction_amount'].append(amount)
                columns['State'].append(state)
                columns['Year'].append(year)
                columns['Quarter'].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_top_trans = pd.DataFrame(columns)
df_top_trans

import os
import json
import pandas as pd

# Define the path to the map user data
path_top_user = '/Users/ptsaravanan/Documents/DATA SCIENCE/Project/CAPSTONE Project/Phonepe Pulse DV/pulse/data/top/user/country/india/state/'
aggregated_state_list = [item for item in os.listdir(path_top_user) if os.path.isdir(os.path.join(path_top_user, item))]

# Initialize a dictionary to store data for DataFrame creation
columns = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Pincode': [],
    'RegisteredUsers': []
}

# Iterate through each state directory
for state in aggregated_state_list:
    cur_state = os.path.join(path_top_user, state)

    # Get list of year directories within the state
    map_year_list = [item for item in os.listdir(cur_state) if os.path.isdir(os.path.join(cur_state, item))]

    # Iterate through each year directory
    for year in map_year_list:
        cur_year = os.path.join(cur_state, year)
        map_file_list = [file for file in os.listdir(cur_year) if file.endswith('.json')]

        # Iterate through each file in the year directory
        for file in map_file_list:
            cur_file = os.path.join(cur_year, file)

            # Ensure it's a file before attempting to open it
            if not os.path.isfile(cur_file):
                continue

            # Read the JSON file and extract required data
            try:
                with open(cur_file, 'r', encoding='utf-8') as data_file:
                    file_content = json.load(data_file)
            except (FileNotFoundError, json.JSONDecodeError):
                continue

            for i in file_content['data']['pincodes']:
                name = i['name']
                registeredUsers = i['registeredUsers']
                columns['Pincode'].append(name)
                columns['RegisteredUsers'].append(registeredUsers)
                columns['State'].append(state)
                columns['Year'].append(year)
                columns['Quarter'].append(int(file.strip('.json')))

# Create DataFrame from the collected data
df_top_user = pd.DataFrame(columns)

df_top_user

#Converting pandas Dataframe into CSV files
df_aggregated_trans.to_csv('agg_trans.csv',index=False)
df_aggregated_user.to_csv('agg_user.csv',index=False)
df_map_trans.to_csv('map_trans.csv',index=False)
df_map_user.to_csv('map_user.csv',index=False)
df_top_trans.to_csv('top_trans.csv',index=False)
df_top_user.to_csv('top_user.csv',index=False)
#Creating a Statenames CSV file 
df_aggregated_trans["State"].to_csv("Statenames.csv",index=False)

import pandas as pd
from sqlalchemy import create_engine, Table, Column, String, Integer, Float, MetaData, text

engine = create_engine("mysql+mysqlconnector://root:Blue9791@localhost/")

# Create a new database if it doesn't exist
with engine.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS phonepe_pulse"))

# Create SQLAlchemy engine and connect to MySQL
engine = create_engine("mysql+mysqlconnector://root:Blue9791@localhost/phonepe_pulse")

# MetaData is used to hold information about tables and database
metadata = MetaData()

# Define table structures
agg_trans = Table('agg_trans', metadata,
                  Column('State', String(100)),
                  Column('Year', Integer),
                  Column('Quarter', Integer),
                  Column('Transaction_type', String(100)),
                  Column('Transaction_count', Integer),
                  Column('Transaction_amount', Float))

agg_user = Table('agg_user', metadata,
                 Column('State', String(100)),
                 Column('Year', Integer),
                 Column('Quarter', Integer),
                 Column('Brand', String(100)),
                 Column('Count', Integer),
                 Column('Percentage', Float))

# Continue with other tables in a similar fashion
map_trans = Table('map_trans', metadata,
                  Column('State', String(100)),
                  Column('Year', Integer),
                  Column('Quarter', Integer),
                  Column('District', String(100)),
                  Column('Count', Integer),
                  Column('Amount', Float))

map_user = Table('map_user', metadata,
                 Column('State', String(100)),
                 Column('Year', Integer),
                 Column('Quarter', Integer),
                 Column('District', String(100)),
                 Column('RegisteredUser', Integer),
                 Column('AppOpens', Integer))

top_trans = Table('top_trans', metadata,
                  Column('State', String(100)),
                  Column('Year', Integer),
                  Column('Quarter', Integer),
                  Column('Pincode', Integer),
                  Column('Transaction_count', Integer),
                  Column('Transaction_amount', Float))

top_user = Table('top_user', metadata,
                 Column('State', String(100)),
                 Column('Year', Integer),
                 Column('Quarter', Integer),
                 Column('Pincode', Integer),
                 Column('RegisteredUsers', Integer))

# Create tables in the database
metadata.create_all(engine)

# Load CSV files into the SQLAlchemy tables
agg_trans_df = pd.read_csv("agg_trans.csv")
agg_user_df = pd.read_csv("agg_user.csv")
map_trans_df = pd.read_csv("map_trans.csv")
map_user_df = pd.read_csv("map_user.csv")
top_trans_df = pd.read_csv("top_trans.csv")
top_user_df = pd.read_csv("top_user.csv")

# Use pandas to_sql to insert data into SQLAlchemy tables
agg_trans_df.to_sql('agg_trans', engine, if_exists='append', index=False)
agg_user_df.to_sql('agg_user', engine, if_exists='append', index=False)
map_trans_df.to_sql('map_trans', engine, if_exists='append', index=False)
map_user_df.to_sql('map_user', engine, if_exists='append', index=False)
top_trans_df.to_sql('top_trans', engine, if_exists='append', index=False)
top_user_df.to_sql('top_user', engine, if_exists='append', index=False)
